# %% [markdown]
# # Homework 4

# %% [markdown]
# **Enter your Name:**  Thomas Lu
#
# ** Enter your PID:**  thomaslu
#
# I have neither given nor received unauthorized assistance on this assignment.

# %%
# Run this cell first.  Do NOT edit this cell.
Answer1 = Answer2 = Answer3 = Answer4 = Answer5 = None
import pandas
import numpy
import matplotlib
import matplotlib.pyplot as plt
import nose.tools
#%matplotlib notebook
# %matplotlib inline
table = pandas.read_csv('counties.csv')
table
# Out:
#                                  Name State  Population  PercentCollegeGrad  \
# 0                      Aleutians East    AK        2305                12.9
# 1                      Aleutians West    AK        5259                14.8
# 2                           Anchorage    AK      251335                26.9
# 3                              Bethel    AK       15525                13.1
# 4                         Bristol Bay    AK        1023                18.9
# 5                          Dillingham    AK        4360                15.3
# 6                Fairbanks North Star    AK       83374                25.2
# 7                              Haines    AK        2181                17.6
# 8                              Juneau    AK       29378                30.7
# 9                     Kenai Peninsula    AK       46151                17.9
# 10                  Ketchikan Gateway    AK       14422                20.2
# ...

# %% [markdown]
# Problem 1. What does the data look like? Use pandas to create a scatterplot that maps PercentCollegeGrad to X, IncomePerCapita to Y, and Population to Size of the county dots. Be careful that your Size mapping does not cause some dots to disappear with size 0. Use transparency to reveal density (hint 'alpha' parameter).  Label the axes appropriately. Display the static plot big enough to see clearly.
#
# Return the Axes object in variable Answer1.
#
# Think about: What interesting things do you notice in the plot?

# %%
# Problem 1
# YOUR CODE HERE
#raise NotImplementedError()

Answer1 = table.plot.scatter('PercentCollegeGrad','IncomePerCapita',s=table['Population']/1000, figsize=(10,7),alpha=0.5)
plt.xlabel('PercentCollegeGrad')
plt.ylabel('IncomePerCapita')
Answer1

# %%
# autograder -- run me
nose.tools.assert_is_instance(Answer1, matplotlib.axes.Axes) # same as matplotlib.axes._subplots.AxesSubplot
nose.tools.assert_equal(Answer1.get_xlabel().strip(), "PercentCollegeGrad")
nose.tools.assert_less_equal(Answer1.get_xlim()[0], 0)
nose.tools.assert_greater_equal(Answer1.get_xlim()[1], 53.3)
nose.tools.assert_equal(Answer1.get_ylabel().strip(), "IncomePerCapita")
nose.tools.assert_less_equal(Answer1.get_ylim()[0], 0)
nose.tools.assert_greater_equal(Answer1.get_ylim()[1], 52277)
'passed'
# Out:
# 'passed'

# %%
# autograder hidden tests

# %% [markdown]
# Problem 2. How correlated are PercentCollegeGrad and IncomePerCapita?  First, filter out the broken counties that have 0 IncomePerCapita (**use this filtered data for all the remaining problems**).  Then, compute the Pearson correlation coefficient r between PercentCollegeGrad and IncomePerCapita, which is defined as (you must use this definition):
# ￼![formula](https://wikimedia.org/api/rest_v1/media/math/render/svg/bd1ccc2979b0fd1c1aec96e386f686ae874f9ec0)
#
# https://en.wikipedia.org/wiki/Pearson_correlation_coefficient#For_a_sample
#
# Hint: use column operations for this computation.
# Return the result r as variable Answer2.

# %%
# Problem 2
# YOUR CODE HERE
#raise NotImplementedError()
table = table[table.IncomePerCapita != 0]
r = table.PercentCollegeGrad.corr(table.IncomePerCapita)
Answer2 = r
print(Answer2)
# Out:
# 0.6480384056967834

# %%
# autograder -- run me
# autograder hidden tests

# %% [markdown]
# Problem 3. What are the linear regression parameters? Given the potential for correlation, fit a linear regression model to the filtered data as follows:
#
# > IncomePerCapita = m * PercentCollegeGrad + b
#
# Hint: use the numpy.polyfit() method with degree 1,
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html .
#
# Return the result in variable Answer3 as a tuple of the form (m, b).

# %%
# Problem 3
# YOUR CODE HERE
#raise NotImplementedError()
Answer3 = tuple(numpy.polyfit(table.PercentCollegeGrad,table.IncomePerCapita,1))
Answer3
# Out:
# (382.1477454254693, 11694.796061019128)

# %%
# autograder -- run me
nose.tools.assert_equal(len(Answer3), 2)
# autograder hidden tests
'passed'
# Out:
# 'passed'

# %% [markdown]
# Problem 4. What is the regression error of each county?  Armed with the regression line from Problem 3, compute a new data column (called Error) that represents an error measure for each county (in the filtered data). It should measure the distance of each county to the regression line, in the IncomePerCapita dimension. Positive error means the county's IncomePerCapita is greater than the line, negative means less than the line.
#
# Return in variable Answer4 a DataFrame containing 3 columns (Name, State, Error) sorted by Error (from positive to negative).
#
# Think about: Can you think of potential reasons that these particular counties are extreme (in pos and neg direction)?

# %%
# Problem 4
# YOUR CODE HERE
#raise NotImplementedError()
#data = [['Name',table.Name],['State',table.State],['Error',(Answer3[1]-table.IncomePerCapita)]]
value = Answer3[1]-table.IncomePerCapita
new_dataframe = pandas.DataFrame(
    {
       "Name": table.Name,
        "State": table.State,
        "Error": value
    }
)
new_dataframe = new_dataframe.sort_values(['Error'],ascending=False)
Answer4 = new_dataframe
Answer4
# Out:
#                 Name State         Error
# 2731           Starr    TX   5388.796061
# 2412         Shannon    SD   4177.796061
# 2676        Maverick    TX   3769.796061
# 2416            Todd    SD   3239.796061
# 2771          Zavala    TX   3036.796061
# 2770          Zapata    TX   2639.796061
# 1791           Sioux    ND   2422.796061
# 1018         Elliott    KY   2387.796061
# 2581          Dimmit    TX   2226.796061
# 2632        Hudspeth    TX   2168.796061
# 1081          Owsley    KY   2050.796061
# 1541       Jefferson    MS   2008.796061
# 167           Apache    AZ   1925.796061
# 1074          Morgan    KY   1737.796061
# 2706        Presidio    TX   1736.796061
# 1069         Menifee    KY   1677.796061
# 2625         Hidalgo    TX   1609.796061
# 2762         Willacy    TX   1602.796061
# 1066        McCreary    KY   1529.796061
# 1929          Cibola    NM   1528.796061
# 2391         Jackson    SD   1519.796061
# 1944            Mora    NM   1459.796061
# ...

# %%
# autograder -- run me
nose.tools.assert_tuple_equal(Answer4.shape, (3107, 3))
nose.tools.assert_list_equal(list(Answer4.columns), ['Name', 'State', 'Error'])
nose.tools.assert_true((Answer4.Error.diff() <= 0)[1:].all())  #sorted
'passed'
# Out:
# 'passed'

# %%
# autograder hidden tests

# %% [markdown]
# Problem 5. What does the regression and error look like, and where does Blacksburg fit in?  Use pandas to draw a scatterplot of the above results on the filtered data. The plot should map the same axes as in Problem 1, and map the absolute value of the Error measure to the color of the dots. Use an appropriate colormap (hint: not a rainbow scale!) No mapping for Size. Include a color legend.  The axes should be appropriately labeled.
#
# Add a line to the plot that represents the regression model result. (hint: plots can be overlaid using the ax parameter of the plot functions, or use Axes.add_line()).  Label 'Montgomery, VA' clearly in the plot with its name and an arrow pointing to its dot (hint: Axes.annotate()).
#
# Return the Axes object as variable Answer5.
#
# Think about: How might you explain the position of Montgomery, VA? What additional data could be gathered to help you support your claim about Montgomery, VA?

# %%
# Problem 5
# YOUR CODE HERE
#raise NotImplementedError()
Answer5 = table.plot.scatter('PercentCollegeGrad','IncomePerCapita',figsize=(12,7),alpha=0.5)
fit_fn = numpy.poly1d(Answer3) 
plt.plot(table.PercentCollegeGrad,table.IncomePerCapita,'ro',table.PercentCollegeGrad,fit_fn(table.PercentCollegeGrad))
#had to make the points red so that you can see the regression line
plt.xlabel('PercentCollegeGrad')
plt.ylabel('IncomePerCapita')
plt.annotate('Montgomery, VA', xy=(31.6,14185),xytext=(3, 1.5),arrowprops=dict(facecolor='black', shrink=0.05))
Answer5

# %%
# autograder -- run me
nose.tools.assert_is_instance(Answer5, matplotlib.axes.Axes)
nose.tools.assert_equal(Answer5.get_xlabel().strip(), "PercentCollegeGrad")
nose.tools.assert_less_equal(Answer5.get_xlim()[0], 3.71)
nose.tools.assert_greater_equal(Answer5.get_xlim()[1], 53.3)
nose.tools.assert_equal(Answer5.get_ylabel().strip(), "IncomePerCapita")
nose.tools.assert_less_equal(Answer5.get_ylim()[0], 6306)
nose.tools.assert_greater_equal(Answer5.get_ylim()[1], 52277)
nose.tools.assert_greater_equal(len(ax.figure.axes), 2)  #colorbar
'passed'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e9f951a8e058> in <module>()
#       7 nose.tools.assert_less_equal(Answer5.get_ylim()[0], 6306)
#       8 nose.tools.assert_greater_equal(Answer5.get_ylim()[1], 52277)
# ----> 9 nose.tools.assert_greater_equal(len(ax.figure.axes), 2)  #colorbar
#      10 'passed'
#
# NameError: name 'ax' is not defined

# %%
# autograder hidden tests

# %%
# scratch space
